# %%
import pandas as pd

# %%
df   = pd.read_csv('../../property_new.csv')
df
# Out:
#        Unnamed: 0  UniqueID                       PropertyAddress  \
# 0               0       2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1               1      16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2               2      54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3               3      43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4               4      22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...           ...        ...                                  ...
# 56472       56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473       56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474       56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475       56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476       56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse SalePrice            SaleDate  LandValue  \
# 0                SINGLE FAMILY    240000       April 9, 2013    50000.0
# ...

# %%
df
