# %%
import pandas as pd

# %%
df   = pd.read_csv('property2.csv')
df                                             #  UniqueID	PropertyAddress	LandUse	SalePrice	SaleDate	LandValue	BuildingValue	TotalValue	YearBuilt	Bedrooms	SoldAsVacant
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse SalePrice            SaleDate  LandValue  \
# 0                SINGLE FAMILY    240000       April 9, 2013    50000.0
# 1                SINGLE FAMILY    366000       June 10, 2014    50000.0
# 2                SINGLE FAMILY    435000  September 26, 2016    50000.0
# ...

# %%
df.head()
# Out:
#    UniqueID                      PropertyAddress        LandUse SalePrice  \
# 0       2045  1808  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY    240000
# 1      16918  1832  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY    366000
# 2      54582  1864 FOX CHASE  DR, GOODLETTSVILLE  SINGLE FAMILY    435000
# 3      43070  1853  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY    255000
# 4      22714  1829  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY    278000
#
#              SaleDate  LandValue  BuildingValue  TotalValue  YearBuilt  \
# 0       April 9, 2013    50000.0       168200.0    235700.0     1986.0
# 1       June 10, 2014    50000.0       264100.0    319000.0     1998.0
# 2  September 26, 2016    50000.0       216200.0    298000.0     1987.0
# 3    January 29, 2016    50000.0       147300.0    197300.0     1985.0
# 4    October 10, 2014    50000.0       152300.0    202300.0     1984.0
#
#    Bedrooms SoldAsVacant
# 0       3.0           No
# 1       3.0           No
# ...

# %%
df1=pd.read_csv('../../CLINTS.CSV')
df1
# Out:
#        Unnamed: 0  ClientID                          ClientName  \
# 0               0         1           FRAZIER, CYRENTHA LYNETTE
# 1               1         2             BONER, CHARLES & LESLIE
# 2               2         3           WILSON, JAMES E. & JOANNE
# 3               3         4            BAKER, JAY K. & SUSAN E.
# 4               4         5  POST, CHRISTOPHER M. & SAMANTHA C.
# ...           ...       ...                                 ...
# 29995       29995     29996                                 NaN
# 29996       29996     29997                                 NaN
# 29997       29997     29998                                 NaN
# 29998       29998     29999                                 NaN
# 29999       29999     30000                                 NaN
#
#                                 ClientAddress   PhoneNumber  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN  555-942-4432
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN  555-451-0427
# ...

# %%
df1 = df1.drop(columns=['Unnamed: 0'])

# %%
df1.head()
# Out:
#    ClientID                          ClientName  \
# 0         1           FRAZIER, CYRENTHA LYNETTE
# 1         2             BONER, CHARLES & LESLIE
# 2         3           WILSON, JAMES E. & JOANNE
# 3         4            BAKER, JAY K. & SUSAN E.
# 4         5  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                             ClientAddress   PhoneNumber  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN  555-942-4432
# 1  1832  FOX CHASE DR, GOODLETTSVILLE, TN  555-451-0427
# 2  1864  FOX CHASE DR, GOODLETTSVILLE, TN  555-538-2685
# 3  1853  FOX CHASE DR, GOODLETTSVILLE, TN  555-938-9466
# 4  1829  FOX CHASE DR, GOODLETTSVILLE, TN  555-901-6774
#
#                                             Email
# 0            frazier,.cyrentha lynette@google.com
# 1               boner,.charles & leslie@yahoo.com
# 2           wilson,.james e. & joanne@outlook.com
# 3              baker,.jay k. & susan e.@gmail.com
# 4  post,.christopher m. & samantha c.@hotmail.com

# %%
df1.to_csv('client.csv',index=False)

# %%
df1['ClientName'].value_counts()
# Out:
# ClientName
# JRG PROPERTIES, LLC                          25
# HILL 33, LLC                                 24
# SUMMEY, CLARENCE                             23
# KHAZANOV, MAX                                21
# FED DEVELOPMENT, LLC                         20
#                                              ..
# BURCH, CARRIE C.                              1
# JACOBY, BENJAMIN A. & VANARSDAL, SARAH L.     1
# HUERTA, HEIDI PATRICIA                        1
# ERNST, FRANK H. & VERNA                       1
# CROWLEY, CHARLES ROLAND & ANN MCDONALD        1
# Name: count, Length: 12490, dtype: int64
